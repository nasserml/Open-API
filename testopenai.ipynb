# %%
import openai
from dotenv import load_dotenv

# %%
import os
openai.api_key=os.getenv('OPEN_API_KEY')

# %%
import pandas as pd

pd.DataFrame(openai.Model.list()['data'])
# Out:
#                                id object     created         owned_by  \
# 0                       whisper-1  model  1677532384  openai-internal
# 1                         babbage  model  1649358449           openai
# 2                         davinci  model  1649359874           openai
# 3           text-davinci-edit-001  model  1649809179           openai
# 4        babbage-code-search-code  model  1651172509       openai-dev
# 5     text-similarity-babbage-001  model  1651172505       openai-dev
# 6           code-davinci-edit-001  model  1649880484           openai
# 7                text-davinci-001  model  1649364042           openai
# 8                             ada  model  1649357491           openai
# 9        babbage-code-search-text  model  1651172509       openai-dev
# 10             babbage-similarity  model  1651172505       openai-dev
# 11   code-search-babbage-text-001  model  1651172507       openai-dev
# 12                 text-curie-001  model  1649364043           openai
# 13   code-search-babbage-code-001  model  1651172507       openai-dev
# 14             gpt-3.5-turbo-0613  model  1686587434           openai
# 15                   text-ada-001  model  1649364042           openai
# 16        text-similarity-ada-001  model  1651172505       openai-dev
# 17            curie-instruct-beta  model  1649364042           openai
# 18             gpt-3.5-turbo-0301  model  1677649963           openai
# 19                  gpt-3.5-turbo  model  1677610602           openai
# 20           ada-code-search-code  model  1651172505       openai-dev
# 21                 ada-similarity  model  1651172507       openai-dev
# 22       code-search-ada-text-001  model  1651172507       openai-dev
# 23      text-search-ada-query-001  model  1651172505       openai-dev
# 24        davinci-search-document  model  1651172509       openai-dev
# 25           ada-code-search-text  model  1651172510       openai-dev
# 26        text-search-ada-doc-001  model  1651172507       openai-dev
# 27          davinci-instruct-beta  model  1649364042           openai
# 28      text-similarity-curie-001  model  1651172507       openai-dev
# 29       code-search-ada-code-001  model  1651172507       openai-dev
# 30               ada-search-query  model  1651172505       openai-dev
# 31  text-search-davinci-query-001  model  1651172505       openai-dev
# 32             curie-search-query  model  1651172509       openai-dev
# 33           davinci-search-query  model  1651172505       openai-dev
# 34        babbage-search-document  model  1651172510       openai-dev
# 35            ada-search-document  model  1651172507       openai-dev
# 36    text-search-curie-query-001  model  1651172509       openai-dev
# 37    text-search-babbage-doc-001  model  1651172509       openai-dev
# 38          curie-search-document  model  1651172508       openai-dev
# 39      text-search-curie-doc-001  model  1651172509       openai-dev
# 40           babbage-search-query  model  1651172509       openai-dev
# 41               text-babbage-001  model  1649364043           openai
# 42    text-search-davinci-doc-001  model  1651172505       openai-dev
# 43  text-search-babbage-query-001  model  1651172509       openai-dev
# 44               curie-similarity  model  1651172510       openai-dev
# 45         gpt-3.5-turbo-16k-0613  model  1685474247           openai
# 46                          curie  model  1649359874           openai
# 47         text-embedding-ada-002  model  1671217299  openai-internal
# 48              gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 49    text-similarity-davinci-001  model  1651172505       openai-dev
# 50               text-davinci-002  model  1649880484           openai
# 51               text-davinci-003  model  1669599635  openai-internal
# 52             davinci-similarity  model  1651172509       openai-dev
#
#                                            permission  \
# 0   [{'id': 'modelperm-KlsZlfft3Gma8pI6A8rTnyjs', ...
# 1   [{'id': 'modelperm-49FUp5v084tBB49tC4z8LPH5', ...
# 2   [{'id': 'modelperm-U6ZwlyAd0LyMk4rcMdz33Yc3', ...
# 3   [{'id': 'modelperm-otmQSS0hmabtVGHI9QB3bct3', ...
# 4   [{'id': 'modelperm-4qRnA3Hj8HIJbgo0cGbcmErn', ...
# 5   [{'id': 'modelperm-48kcCHhfzvnfY84OtJf5m8Cz', ...
# 6   [{'id': 'modelperm-Foe5Y4TvaKveYxt74oKMw8IB', ...
# 7   [{'id': 'modelperm-MVM5NfoRjXkDve3uQW3YZDDt', ...
# 8   [{'id': 'modelperm-u0nKN4ub7EVQudgMuvCuvDjc', ...
# 9   [{'id': 'modelperm-Lftf8H4ZPDxNxVs0hHPJBUoe', ...
# 10  [{'id': 'modelperm-mS20lnPqhebTaFPrcCufyg7m', ...
# 11  [{'id': 'modelperm-EC5ASz4NLChtEV1Cwkmrwm57', ...
# 12  [{'id': 'modelperm-8InhPV3CZfN3F5QHKoJd4zRD', ...
# 13  [{'id': 'modelperm-64LWHdlANgak2rHzc3K5Stt0', ...
# 14  [{'id': 'modelperm-5XP2xnkaNkMxRS436DXZ8FYy', ...
# 15  [{'id': 'modelperm-KN5dRBCEW4az6gwcGXkRkMwK', ...
# 16  [{'id': 'modelperm-DdCqkqmORpqxqdg4TkFRAgmw', ...
# 17  [{'id': 'modelperm-bsg59MlOi88CMf1MjnIKrT5a', ...
# 18  [{'id': 'modelperm-v60zSOg6kSqrIjHyLT3wC4Io', ...
# 19  [{'id': 'modelperm-LeYYAMp5mu0Qkfui5StsNiib', ...
# 20  [{'id': 'modelperm-wa8tg4Pi9QQNaWdjMTM8dkkx', ...
# 21  [{'id': 'modelperm-LtSIwCEReeDcvGTmM13gv6Fg', ...
# 22  [{'id': 'modelperm-JBssaJSmbgvJfTkX71y71k2J', ...
# 23  [{'id': 'modelperm-1YiiBMYC8it0mpQCBK7t8uSP', ...
# 24  [{'id': 'modelperm-M43LVJQRGxz6ode34ctLrCaG', ...
# 25  [{'id': 'modelperm-kFc17wOI4d1FjZEaCqnk4Frg', ...
# 26  [{'id': 'modelperm-kbHvYouDlkD78ehcmMOGdKpK', ...
# 27  [{'id': 'modelperm-k9kuMYlfd9nvFiJV2ug0NWws', ...
# 28  [{'id': 'modelperm-6dgTTyXrZE7d53Licw4hYkvd', ...
# 29  [{'id': 'modelperm-8soch45iiGvux5Fg1ORjdC4s', ...
# 30  [{'id': 'modelperm-b753xmIzAUkluQ1L20eDZLtQ', ...
# 31  [{'id': 'modelperm-9McKbsEYSaDshU9M3bp6ejUb', ...
# 32  [{'id': 'modelperm-sIbfSwzVpVBtymQgOQSLBpxe', ...
# 33  [{'id': 'modelperm-lYkiTZMmJMWm8jvkPx2duyHE', ...
# 34  [{'id': 'modelperm-5qFV9kxCRGKIXpBEP75chmp7', ...
# 35  [{'id': 'modelperm-8qUMuMAbo4EwedbGamV7e9hq', ...
# 36  [{'id': 'modelperm-Iion0NCpsXPNtIkQ0owQLi7V', ...
# 37  [{'id': 'modelperm-ao2r26P2Th7nhRFleHwy2gn5', ...
# 38  [{'id': 'modelperm-LDsN5wW8eKVuh1OsyciHntE9', ...
# 39  [{'id': 'modelperm-taUGRSku7bQLa24SNIwYPEsi', ...
# 40  [{'id': 'modelperm-wSs1hMXDKsrcErlbN8HmzlLE', ...
# 41  [{'id': 'modelperm-a3Ph5FIBbJxsoA4wvx7VYC7R', ...
# 42  [{'id': 'modelperm-qhSf1j2MJMujcu3t7cHnF1DN', ...
# 43  [{'id': 'modelperm-Kg70kkFxD93QQqsVe4Zw8vjc', ...
# 44  [{'id': 'modelperm-zhWKExSloaQiJgzjVHFmh2wR', ...
# 45  [{'id': 'modelperm-wzYEyRA76GfGVQ40hnRtOrPX', ...
# 46  [{'id': 'modelperm-oPaljeveTjEIDbhDjzFiyf4V', ...
# 47  [{'id': 'modelperm-3nA9lRH2BRk4nbMOp5RUC5Pl', ...
# 48  [{'id': 'modelperm-1lio0GT8TXWtxj9U96NQ32HD', ...
# 49  [{'id': 'modelperm-OvmcfYoq5V9SF9xTYw1Oz6Ue', ...
# 50  [{'id': 'modelperm-l4EU6QlN1HcS0so0jU16kyg8', ...
# 51  [{'id': 'modelperm-OCpZQfjQpoXnuT1DcEr3TtVy', ...
# 52  [{'id': 'modelperm-lYYgng3LM0Y97HvB5CDc8no2', ...
#
#                              root parent
# 0                       whisper-1   None
# 1                         babbage   None
# 2                         davinci   None
# 3           text-davinci-edit-001   None
# 4        babbage-code-search-code   None
# 5     text-similarity-babbage-001   None
# 6           code-davinci-edit-001   None
# 7                text-davinci-001   None
# 8                             ada   None
# 9        babbage-code-search-text   None
# 10             babbage-similarity   None
# 11   code-search-babbage-text-001   None
# 12                 text-curie-001   None
# 13   code-search-babbage-code-001   None
# 14             gpt-3.5-turbo-0613   None
# 15                   text-ada-001   None
# 16        text-similarity-ada-001   None
# 17            curie-instruct-beta   None
# 18             gpt-3.5-turbo-0301   None
# 19                  gpt-3.5-turbo   None
# 20           ada-code-search-code   None
# 21                 ada-similarity   None
# 22       code-search-ada-text-001   None
# 23      text-search-ada-query-001   None
# 24        davinci-search-document   None
# 25           ada-code-search-text   None
# 26        text-search-ada-doc-001   None
# 27          davinci-instruct-beta   None
# 28      text-similarity-curie-001   None
# 29       code-search-ada-code-001   None
# 30               ada-search-query   None
# 31  text-search-davinci-query-001   None
# 32             curie-search-query   None
# 33           davinci-search-query   None
# 34        babbage-search-document   None
# 35            ada-search-document   None
# 36    text-search-curie-query-001   None
# 37    text-search-babbage-doc-001   None
# 38          curie-search-document   None
# 39      text-search-curie-doc-001   None
# 40           babbage-search-query   None
# 41               text-babbage-001   None
# 42    text-search-davinci-doc-001   None
# 43  text-search-babbage-query-001   None
# 44               curie-similarity   None
# 45         gpt-3.5-turbo-16k-0613   None
# 46                          curie   None
# 47         text-embedding-ada-002   None
# 48              gpt-3.5-turbo-16k   None
# 49    text-similarity-davinci-001   None
# 50               text-davinci-002   None
# 51               text-davinci-003   None
# 52             davinci-similarity   None

# %%
## Chat Completion API and Completion API
## Completion API
response=openai.Completion.create(
    model='text-curie-001',
    prompt='what is the capital of Indai?'
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 ## Chat Completion API and Completion API
#       2 ## Completion API
# ----> 3 response=openai.Completion.create(
#       4     model='text-curie-001',
#       5     prompt='what is the capital of Indai?'
#       6 )
#
# File f:\artificial intelegnce\study\ML End To End Projects Krish Naik\github\Open-API\venv\lib\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File f:\artificial intelegnce\study\ML End To End Projects Krish Naik\github\Open-API\venv\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File f:\artificial intelegnce\study\ML End To End Projects Krish Naik\github\Open-API\venv\lib\site-packages\openai\api_requestor.py:298, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#    (...)
#     296         request_timeout=request_timeout,
#     297     )
# --> 298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File f:\artificial intelegnce\study\ML End To End Projects Krish Naik\github\Open-API\venv\lib\site-packages\openai\api_requestor.py:700, in APIRequestor._interpret_response(self, result, stream)
#     692     return (
#     693         self._interpret_response_line(
#     694             line, result.status_code, result.headers, stream=True
#     695         )
#     696         for line in parse_stream(result.iter_lines())
#     697     ), True
#     698 else:
#     699     return (
# --> 700         self._interpret_response_line(
#     701             result.content.decode("utf-8"),
#     702             result.status_code,
#     703             result.headers,
#     704             stream=False,
#     705         ),
#     706         False,
#     707     )
#
# File f:\artificial intelegnce\study\ML End To End Projects Krish Naik\github\Open-API\venv\lib\site-packages\openai\api_requestor.py:763, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     761 stream_error = stream and "error" in resp.data
#     762 if stream_error or not 200 <= rcode < 300:
# --> 763     raise self.handle_error_response(
#     764         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     765     )
#     766 return resp
#
# RateLimitError: Your access was terminated due to violation of our policies, please check your email for more information. If you believe this is in error and would like to appeal, please contact us through our help center at help.openai.com.
